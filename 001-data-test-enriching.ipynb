# %%
#import
import pandas as pd

pd.set_option('display.max_columns', 100)

# %%
solutions_df = pd.read_csv('./data/submission.csv')
diamonds_test = pd.read_csv('./data/diamonds_test.csv')

# %%
solutions_df
# Out:
#           id      price
# 0          0  2924.4974
# 1          1  5399.3373
# 2          2  9847.4092
# 3          3  4094.3990
# 4          4  1697.8114
# ...      ...        ...
# 13480  13480  1662.0140
# 13481  13481  2536.6023
# 13482  13482  2886.0555
# 13483  13483  2162.7330
# 13484  13484   831.4249
#
# [13485 rows x 2 columns]

# %%
diamonds_test
# Out:
#           id  carat        cut color clarity  depth  table     x     y     z  \
# 0          0   0.79  Very Good     F     SI1   62.7   60.0  5.82  5.89  3.67
# 1          1   1.20      Ideal     J     VS1   61.0   57.0  6.81  6.89  4.18
# 2          2   1.57    Premium     H     SI1   62.2   61.0  7.38  7.32  4.57
# 3          3   0.90  Very Good     F     SI1   63.8   54.0  6.09  6.13  3.90
# 4          4   0.50  Very Good     F     VS1   62.9   58.0  5.05  5.09  3.19
# ...      ...    ...        ...   ...     ...    ...    ...   ...   ...   ...
# 13480  13480   0.57      Ideal     E     SI1   61.9   56.0  5.35  5.32  3.30
# 13481  13481   0.71      Ideal     I     VS2   62.2   55.0  5.71  5.73  3.56
# 13482  13482   0.70      Ideal     F     VS1   61.6   55.0  5.75  5.71  3.53
# 13483  13483   0.70  Very Good     F     SI2   58.8   57.0  5.85  5.89  3.45
# 13484  13484   0.40      Ideal     I    VVS2   62.4   55.0  4.70  4.73  2.94
#
#                 city
# 0          Amsterdam
# ...

# %%
diamonds_test_price = pd.merge(diamonds_test, solutions_df, on="id")

# %%
diamonds_test_price
# Out:
#           id  carat        cut color clarity  depth  table     x     y     z  \
# 0          0   0.79  Very Good     F     SI1   62.7   60.0  5.82  5.89  3.67
# 1          1   1.20      Ideal     J     VS1   61.0   57.0  6.81  6.89  4.18
# 2          2   1.57    Premium     H     SI1   62.2   61.0  7.38  7.32  4.57
# 3          3   0.90  Very Good     F     SI1   63.8   54.0  6.09  6.13  3.90
# 4          4   0.50  Very Good     F     VS1   62.9   58.0  5.05  5.09  3.19
# ...      ...    ...        ...   ...     ...    ...    ...   ...   ...   ...
# 13480  13480   0.57      Ideal     E     SI1   61.9   56.0  5.35  5.32  3.30
# 13481  13481   0.71      Ideal     I     VS2   62.2   55.0  5.71  5.73  3.56
# 13482  13482   0.70      Ideal     F     VS1   61.6   55.0  5.75  5.71  3.53
# 13483  13483   0.70  Very Good     F     SI2   58.8   57.0  5.85  5.89  3.45
# 13484  13484   0.40      Ideal     I    VVS2   62.4   55.0  4.70  4.73  2.94
#
#                 city      price
# ...

# %%
columns = ['price'] + [col for col in diamonds_test_price.columns if col != 'price']
diamonds_test_price = diamonds_test_price[columns]

# %%
diamonds_test_price = diamonds_test_price.drop('id', axis=1)
diamonds_test_price
# Out:
#            price  carat        cut color clarity  depth  table     x     y  \
# 0      2924.4974   0.79  Very Good     F     SI1   62.7   60.0  5.82  5.89
# 1      5399.3373   1.20      Ideal     J     VS1   61.0   57.0  6.81  6.89
# 2      9847.4092   1.57    Premium     H     SI1   62.2   61.0  7.38  7.32
# 3      4094.3990   0.90  Very Good     F     SI1   63.8   54.0  6.09  6.13
# 4      1697.8114   0.50  Very Good     F     VS1   62.9   58.0  5.05  5.09
# ...          ...    ...        ...   ...     ...    ...    ...   ...   ...
# 13480  1662.0140   0.57      Ideal     E     SI1   61.9   56.0  5.35  5.32
# 13481  2536.6023   0.71      Ideal     I     VS2   62.2   55.0  5.71  5.73
# 13482  2886.0555   0.70      Ideal     F     VS1   61.6   55.0  5.75  5.71
# 13483  2162.7330   0.70  Very Good     F     SI2   58.8   57.0  5.85  5.89
# 13484   831.4249   0.40      Ideal     I    VVS2   62.4   55.0  4.70  4.73
#
#           z           city
# 0      3.67      Amsterdam
# ...

# %%
df_cleaned = pd.read_csv('./data/df_cleaned.csv')

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40455 entries, 0 to 40454
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  40455 non-null  int64
#  1   price       40455 non-null  int64
#  2   carat       40455 non-null  float64
#  3   depth       40455 non-null  float64
#  4   table       40455 non-null  float64
#  5   x           40455 non-null  float64
#  6   y           40455 non-null  float64
#  7   z           40455 non-null  float64
#  8   city        40455 non-null  object
#  9   clarity     40455 non-null  object
#  10  color       40455 non-null  object
#  11  cut         40455 non-null  object
# dtypes: float64(6), int64(2), object(4)
# memory usage: 3.7+ MB

# %%
df_cleaned = df_cleaned.drop('Unnamed: 0', axis=1)

# %%
df_cleaned
# Out:
#        price  carat  depth  table     x     y     z           city clarity  \
# 0       4268   1.21   62.4   58.0  6.83  6.79  4.25          Dubai     VS2
# 1        505   0.32   63.0   57.0  4.35  4.38  2.75       Kimberly     VS2
# 2       2686   0.71   65.5   55.0  5.62  5.53  3.65      Las Vegas     VS1
# 3        738   0.41   63.8   56.0  4.68  4.72  3.00       Kimberly     SI1
# 4       4882   1.02   60.5   59.0  6.55  6.51  3.95          Dubai     SI1
# ...      ...    ...    ...    ...   ...   ...   ...            ...     ...
# 40450   5850   1.08   61.9   54.0  6.64  6.61  4.10        Antwerp     VS2
# 40451   6300   1.15   61.8   55.0  6.73  6.76  4.17     Luxembourg     SI1
# 40452   1800   0.53   61.4   57.0  5.18  5.20  3.19       Kimberly     VS1
# 40453   2368   0.66   60.8   58.0  5.67  5.64  3.44      Amsterdam     VS1
# 40454   3872   1.10   61.9   56.0  6.59  6.63  4.09  New York City      I1
#
#       color        cut
# 0         J    Premium
# ...

# %%
diamonds_test_price
# Out:
#            price  carat        cut color clarity  depth  table     x     y  \
# 0      2924.4974   0.79  Very Good     F     SI1   62.7   60.0  5.82  5.89
# 1      5399.3373   1.20      Ideal     J     VS1   61.0   57.0  6.81  6.89
# 2      9847.4092   1.57    Premium     H     SI1   62.2   61.0  7.38  7.32
# 3      4094.3990   0.90  Very Good     F     SI1   63.8   54.0  6.09  6.13
# 4      1697.8114   0.50  Very Good     F     VS1   62.9   58.0  5.05  5.09
# ...          ...    ...        ...   ...     ...    ...    ...   ...   ...
# 13480  1662.0140   0.57      Ideal     E     SI1   61.9   56.0  5.35  5.32
# 13481  2536.6023   0.71      Ideal     I     VS2   62.2   55.0  5.71  5.73
# 13482  2886.0555   0.70      Ideal     F     VS1   61.6   55.0  5.75  5.71
# 13483  2162.7330   0.70  Very Good     F     SI2   58.8   57.0  5.85  5.89
# 13484   831.4249   0.40      Ideal     I    VVS2   62.4   55.0  4.70  4.73
#
#           z           city
# 0      3.67      Amsterdam
# ...

# %%
df_cleaned = df_cleaned[diamonds_test_price.columns]

# %%
df_cleaned.columns.equals(diamonds_test_price.columns)
# Out:
# True

# %%
concat = pd.concat([df_cleaned, diamonds_test_price], ignore_index=True)

# %%
concat
# Out:
#            price  carat        cut color clarity  depth  table     x     y  \
# 0      4268.0000   1.21    Premium     J     VS2   62.4   58.0  6.83  6.79
# 1       505.0000   0.32  Very Good     H     VS2   63.0   57.0  4.35  4.38
# 2      2686.0000   0.71       Fair     G     VS1   65.5   55.0  5.62  5.53
# 3       738.0000   0.41       Good     D     SI1   63.8   56.0  4.68  4.72
# 4      4882.0000   1.02      Ideal     G     SI1   60.5   59.0  6.55  6.51
# ...          ...    ...        ...   ...     ...    ...    ...   ...   ...
# 53935  1662.0140   0.57      Ideal     E     SI1   61.9   56.0  5.35  5.32
# 53936  2536.6023   0.71      Ideal     I     VS2   62.2   55.0  5.71  5.73
# 53937  2886.0555   0.70      Ideal     F     VS1   61.6   55.0  5.75  5.71
# 53938  2162.7330   0.70  Very Good     F     SI2   58.8   57.0  5.85  5.89
# 53939   831.4249   0.40      Ideal     I    VVS2   62.4   55.0  4.70  4.73
#
#           z           city
# 0      4.25          Dubai
# ...

# %%
concat.to_csv('./data/diamonds_full.csv')
